# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plotting

# Define the array of points
points = np.array([
    [ 0.2,         0.2,         0.0],
    [ 0.44748737,  0.44748737,  0.0],
    [ 0.69497475,  0.69497475,  0.0],
    [-0.2,         0.2,         0.0],
    [-0.44748737,  0.44748737,  0.0],
    [-0.69497475,  0.69497475,  0.0],
    [ 0.2,         0.12,        0.0],
    [ 0.44748737,  0.36748737,  0.0],
    [ 0.69497475,  0.61497475,  0.0],
    [-0.2,         0.12,        0.0],
    [-0.44748737,  0.36748737,  0.0],
    [-0.69497475,  0.61497475,  0.0],
    [ 0.2,         0.04,        0.0],
    [ 0.44748737,  0.28748737,  0.0],
    [ 0.69497475,  0.53497475,  0.0],
    [-0.2,         0.04,        0.0],
    [-0.44748737,  0.28748737,  0.0],
    [-0.69497475,  0.53497475,  0.0],
    [ 0.2,        -0.04,        0.0],
    [ 0.44748737,  0.20748737,  0.0],
    [ 0.69497475,  0.45497475,  0.0],
    [-0.2,        -0.04,        0.0],
    [-0.44748737,  0.20748737,  0.0],
    [-0.69497475,  0.45497475,  0.0]
])

# Create the figure and 3D axis
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot the points
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='blue', s=50)

# Set axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot of Points')

# Equal aspect ratio for all axes
ax.set_box_aspect([np.ptp(points[:, 0]), np.ptp(points[:, 1]), np.ptp(points[:, 2]) + 1e-3])  # add small value to avoid zero division

# Show the plot
plt.show()
